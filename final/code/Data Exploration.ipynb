# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv('gaming_video_stats.csv', encoding='latin-1')
df['PublishedAt'] = pd.to_datetime(df['publishedAt'], errors='coerce')
df.dropna()
df['logViews'] = np.log(df['viewCount']+1)

# %%
df.columns
# Out:
# Index([u'viewCount', u'likeCount', u'dislikeCount', u'favoriteCount',
#        u'commentCount', u'title', u'description', u'publishedAt', u'video Id',
#        u'channel Id'],
#       dtype='object')

# %% [markdown]
# High level overview of what I want to do is this:
#
# The `prolific_channels` pandas dataframe has a bunch of entries corresponding to videos from channels that have published more than 50 videos. What I want to be able to do is, for each channel that has more than 50 videos, get the rowHash (index in the dataframe) of the most recently uploaded video. Then, for each of those most recently uploaded videos per channel, we want to get statistics for the last 10 or so videos uploaded before that one. Each of these stats will be a feature in our regression. And then after defining a dataframe for that (which I'll refer to as `df`) and putting those features in it, we call a GradientBoostingRegressor as follows.

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

#features = ['last_video_views', '2nd_to_last_views', ... 'views_from_10_videos_ago',
#            'last_video_comment_count', same for the others...]

X = df[features]
y = df['Views']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    
reg = GradientBoostingRegressor()
reg.fit(X_train, y_train)
print "R^2: {0}".format(reg.score(X_test, y_test))

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,12))
sns.barplot(x=reg.feature_importances_, y=features)

# %% [markdown]
# And then in addition to that regressor, which is a view count predictor based on stats specific to the channel in question, we'll also want another regressor that looks at coarser channel stats like that other group did (total subscribers, total videos, total view counts, etc), and then just based on those try to come up with an estimate of the view counts for the most recent uploads to a channel. And then combine those regressors somehow.

# %%
channels = {}
for _, video in df.iterrows():
    channel_id = video['channel Id']
    if not channel_id in channels:
        channels[channel_id] = [video]
    else:
        channels[channel_id].append(video)
for channel_id in channels:
    channels[channel_id] = sorted(channels[channel_id], key=lambda v: v['PublishedAt'])

# %%
from random import shuffle
def prediction_answer_and_feature_extractor(channel, n):
    """
    I'm assuming the thing that's passed in is a list of videos,
    in other words a channel is a value in the channels dict.
    This also assumes that 
    
    This takes one of those entries and returns a tuple, one value of which
    is the correct view count that we want to predict for the most recent video
    posted to the channel, and the second is a dictionary containing feature names
    and feature values of the previous 10 videos before the most recent one.
    """
    if len(channel) < n+1:
        raise Exception("Not enough videos in channel to create a feature vector.")
        
    video_stat_names = ['likeCount', 'dislikeCount', 'viewCount', 
                'commentCount']
    correct_prediction = channel[-1]['logViews']
    feature_values = []
    feature_names = []
    tmp_channel = list(channel)
    shuffle(tmp_channel)
    for i in range(-2,-n-2,-1):
        feature_values += list(tmp_channel[i][video_stat_names])
        feature_names += [name + "%d"%(i+1) for name in video_stat_names]
    return (correct_prediction, dict(zip(feature_names, feature_values)))

# %% [markdown]
# The above will definitely fail since the entries in ~channels~ are often going to be shorter than n (which we'll set to 5 or 10 or something). Which is why we need to use the YouTube API to loop through all channel ids in channels and populate the list with the last 15 videos posted to that channel.

# %%
prolific_channels = {k:v for k, v in channels.items() if 11 < len(v)}

# %%
prediction_answer_and_feature_extractor(prolific_channels.iteritems()[0][1], 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-328b4e94a37a> in <module>
# ----> 1 prediction_answer_and_feature_extractor(prolific_channels.iteritems()[0][1], 5)
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
data = []
for channel_id, vids in nlp_channels.items():
    answer, vid_features = prediction_answer_and_feature_extractor(vids, 5)
    vid_features['trueViewCount'] = answer
    data.append(vid_features)

# %%
channel
# Out:
# 'UCa0o4WDOq1kJAyMETrPnpQg'

# %%
Y = pd.DataFrame(answers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-fe8164b1f182> in <module>
# ----> 1 Y = pd.DataFrame(answers)
#
# NameError: name 'answers' is not defined

# %%
df.columns
# Out:
# Index([u'commentCount-1', u'commentCount-10', u'commentCount-2',
#        u'commentCount-3', u'commentCount-4', u'commentCount-5',
#        u'commentCount-6', u'commentCount-7', u'commentCount-8',
#        u'commentCount-9', u'dislikeCount-1', u'dislikeCount-10',
#        u'dislikeCount-2', u'dislikeCount-3', u'dislikeCount-4',
#        u'dislikeCount-5', u'dislikeCount-6', u'dislikeCount-7',
#        u'dislikeCount-8', u'dislikeCount-9', u'favoriteCount-1',
#        u'favoriteCount-10', u'favoriteCount-2', u'favoriteCount-3',
#        u'favoriteCount-4', u'favoriteCount-5', u'favoriteCount-6',
#        u'favoriteCount-7', u'favoriteCount-8', u'favoriteCount-9',
#        u'likeCount-1', u'likeCount-10', u'likeCount-2', u'likeCount-3',
#        u'likeCount-4', u'likeCount-5', u'likeCount-6', u'likeCount-7',
#        u'likeCount-8', u'likeCount-9', u'trueViewCount', u'viewCount-1',
#        u'viewCount-10', u'viewCount-2', u'viewCount-3', u'viewCount-4',
#        u'viewCount-5', u'viewCount-6', u'viewCount-7', u'viewCount-8',
#        u'viewCount-9'],
#       dtype='object')

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

features = ['likeCount', 'dislikeCount', 'viewCount', 'commentCount']
real_features = [name+'-%d'%i for i in range(1,6) for name in features]
df = pd.DataFrame(data)
df = df.dropna()
X = df[real_features]
y = df['trueViewCount']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    
reg = GradientBoostingRegressor()
reg.fit(X_train, y_train)
print("R^2: {0}".format(reg.score(X_test, y_test)))
sns.set_style('whitegrid')
plt.figure(figsize=(10,12))
sns.barplot(x=reg.feature_importances_, y=real_features)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-c1f11b6d438f> in <module>
#       7 df = pd.DataFrame(data)
#       8 df = df.dropna()
# ----> 9 X = df[real_features]
#      10 y = df['trueViewCount']
#      11 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
#
# ~/Desktop/Fall 2018/CS 221/project/.venv3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/Desktop/Fall 2018/CS 221/project/.venv3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/Desktop/Fall 2018/CS 221/project/.venv3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['likeCount-1' 'dislikeCount-1' 'viewCount-1' 'commentCount-1'\n 'likeCount-2' 'dislikeCount-2' 'viewCount-2' 'commentCount-2'\n 'likeCount-3' 'dislikeCount-3' 'viewCount-3' 'commentCount-3'\n 'likeCount-4' 'dislikeCount-4' 'viewCount-4' 'commentCount-4'\n 'likeCount-5' 'dislikeCount-5' 'viewCount-5' 'commentCount-5'] not in index"

# %%
real_features #R^2 = .646
# Out:
# ['likeCount-1',
#  'dislikeCount-1',
#  'viewCount-1',
#  'favoriteCount-1',
#  'commentCount-1',
#  'likeCount-2',
#  'dislikeCount-2',
#  'viewCount-2',
#  'favoriteCount-2',
#  'commentCount-2',
#  'likeCount-3',
#  'dislikeCount-3',
#  'viewCount-3',
#  'favoriteCount-3',
#  'commentCount-3',
#  'likeCount-4',
#  'dislikeCount-4',
#  'viewCount-4',
#  'favoriteCount-4',
#  'commentCount-4',
#  'likeCount-5',
#  'dislikeCount-5',
#  'viewCount-5',
#  'favoriteCount-5',
#  'commentCount-5']

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

# %%
xgb = XGBRegressor()

xgb.fit(X_train, y_train)
print(xgb.score(X_test, y_test))
y_pred = xgb.predict(X_test)
plot_df = pd.DataFrame(y_pred, columns=['log(Predictions)'])
plot_df['log(True)'] = np.array(y_test)
sns.regplot(x='log(Predictions)', y='log(True)', data=plot_df)
# Out:
# 0.7315795291960427
# /Users/jonbraatz/Desktop/Fall 2018/CS 221/project/.venv3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
XGBRegressor()
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_test
i = 0
for
# Out:
# 2590     2.639057
# 1893     9.138952
# 1351     3.610918
# 1367     5.123964
# 2788     4.779123
# 458      8.235891
# 2318     9.115810
# 3194     5.379897
# 395      3.806662
# 1970     7.174724
# 2323     5.973810
# 3142     4.317488
# 1603     6.152733
# 2658     5.517453
# 1995     3.970292
# 1887     6.806829
# 1283     7.495542
# 2623     5.953243
# 1949    10.506026
# 124      5.517453
# 1688     9.869207
# 3134    11.179939
# 53       8.148446
# 1833     8.850231
# 1671     2.079442
# 553      5.918894
# 1016     6.862758
# 462      4.262680
# 2654     5.958425
# 2838     4.454347
#           ...
# 1809     4.969813
# 807      6.466145
# 3141    10.315730
# 2478    11.396830
# 1400     6.893656
# 900      6.650279
# 1900     4.867534
# 73       6.049733
# 1427     3.496508
# 92       1.609438
# 2801     6.857514
# 1923     6.682109
# 1353     5.752573
# 1270     5.017280
# 2662     3.828641
# 2380     1.609438
# 1058     2.639057
# 1038     6.194405
# 1691     3.970292
# 1462    11.008479
# 1944     1.098612
# 1947    11.141354
# 1676     3.583519
# 613      8.418698
# 414      4.094345
# 3168     7.536364
# 1244     6.403574
# 2082     5.834811
# 3181     3.688879
# 2752     5.123964
# Name: trueViewCount, Length: 1028, dtype: float64

# %%
import spacy

nlp = spacy.load('en_core_web_lg')

# %%
nlp_channels = {}
for channel_id, vids in prolific_channels.items():
    title_desc = nlp("{} {}".format(vids[-1]['title'], vids[-1]['description']))
    similarities = [title_desc.similarity(nlp("{} {}".format(vid['title'], vid['description']))) for vid in vids[:-1]]
    vids_and_sims = zip(similarities, vids)
    nlp_channels[channel_id] = [v[1] for v in sorted(vids_and_sims, key=lambda k:k[0])]

# %%
len(nlp_channels)
# Out:
# 1435

# %%
nlp_channels
# Out:
# {'UCwRGQapSgTW9xba17OCjgXA': [viewCount                                    111
#   likeCount                                      3
#   dislikeCount                                   0
#   favoriteCount                                  0
#   commentCount                                   1
#   title            Team Fortress 2 - Messing About
#   description                           Fun! Later
#   publishedAt             2012-06-03T20:06:40.000Z
#   video Id                             jfGBh5IM38c
#   channel Id              UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                  2012-06-03 20:06:40
#   logViews                                  4.7185
#   Name: 17, dtype: object,
#   viewCount                                                     1185
#   likeCount                                                       10
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                    15
#   title            (Closed) Join My Survival Server! (No Griefing...
#   description                               Ip: 178.33.226.114:25587
#   publishedAt                               2012-05-17T22:05:56.000Z
#   video Id                                               mOmSOBbRGTA
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-05-17 22:05:56
#   logViews                                                   7.07834
#   Name: 19, dtype: object,
#   viewCount                                                     1200
#   likeCount                                                        9
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                     6
#   title                              Minecraft - Sand Condo Showcase
#   description      Something new besides LP's\r\n\r\nTwitter: htt...
#   publishedAt                               2013-02-16T19:47:58.000Z
#   video Id                                               yFUYaKJNMSM
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2013-02-16 19:47:58
#   logViews                                                   7.09091
#   Name: 1, dtype: object,
#   viewCount                                                     7225
#   likeCount                                                       27
#   dislikeCount                                                     3
#   favoriteCount                                                    0
#   commentCount                                                    21
#   title              How to use ChestShop Plugin for Minecraft 1.2.5
#   description      Hope this tutorial helps!\r\nChestShop Link: h...
#   publishedAt                               2012-03-26T20:52:51.000Z
#   video Id                                               vhvxyLLYHkI
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-03-26 20:52:51
#   logViews                                                   8.88544
#   Name: 24, dtype: object,
#   viewCount                                                86
#   likeCount                                                 4
#   dislikeCount                                              0
#   favoriteCount                                             0
#   commentCount                                              3
#   title            Minecraft - Let's Play Ep 4: Getting Iron!
#   description                             So...Much.....Iron!
#   publishedAt                        2012-05-10T16:20:34.000Z
#   video Id                                        GzWHoYFL1Sg
#   channel Id                         UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                             2012-05-10 16:20:34
#   logViews                                            4.46591
#   Name: 20, dtype: object,
#   viewCount                                                     4313
#   likeCount                                                       21
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                    10
#   title                 Minecraft - Modern House Design by GioIZhere
#   description      Hopefully you will like this house design. Her...
#   publishedAt                               2012-06-11T13:26:40.000Z
#   video Id                                               r3YSb6mVhe8
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-06-11 13:26:40
#   logViews                                                   8.36962
#   Name: 16, dtype: object,
#   viewCount                                                      213
#   likeCount                                                        5
#   dislikeCount                                                     3
#   favoriteCount                                                    0
#   commentCount                                                    17
#   title                           Top Five/Ten Building Series Idea!
#   description      Send in your world, or send the link to a worl...
#   publishedAt                               2012-10-21T03:38:49.000Z
#   video Id                                               caKERyxM2rs
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-10-21 03:38:49
#   logViews                                                   5.36598
#   Name: 4, dtype: object,
#   viewCount                                                     1211
#   likeCount                                                        8
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                    15
#   title                Minecraft - Let's Play Ep 5: Waraxe and Mace!
#   description      I want to kill things so bad! \r\nMod: http://...
#   publishedAt                               2012-06-14T20:45:04.000Z
#   video Id                                               8QwRWAA-lD4
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-06-14 20:45:04
#   logViews                                                   7.10003
#   Name: 15, dtype: object,
#   viewCount                                                    85424
#   likeCount                                                      261
#   dislikeCount                                                    41
#   favoriteCount                                                    0
#   commentCount                                                    73
#   title             Minecraft Tutorial: How to Grow Carrots/Potatoes
#   description      Hope this helped someone! Leave a comment or a...
#   publishedAt                               2012-10-30T03:04:41.000Z
#   video Id                                               Uztq5Zcfl4A
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-10-30 03:04:41
#   logViews                                                   11.3554
#   Name: 3, dtype: object,
#   viewCount                                                     1019
#   likeCount                                                        8
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     7
#   title            Minecraft - Let's Play Ep 7: This Is Sparta! W...
#   description      Yes! The audio isn't terrible this time! Spart...
#   publishedAt                               2012-06-20T20:44:32.000Z
#   video Id                                               q4UdGWjU2LE
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-06-20 20:44:32
#   logViews                                                   6.92756
#   Name: 13, dtype: object,
#   viewCount                                                       97
#   likeCount                                                        4
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title                Minecraft Let's Play Episode 2 - Make A Farm!
#   description      So now I'm making a farm so I won't starve to ...
#   publishedAt                               2012-04-25T00:24:13.000Z
#   video Id                                               5HAw-KlNRvA
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-04-25 00:24:13
#   logViews                                                   4.58497
#   Name: 22, dtype: object,
#   viewCount                                                      117
#   likeCount                                                        5
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     6
#   title            Minecraft - Let's Play Ep 3: Now with Mo'Creat...
#   description      Ignore me saying "SoCreepers" at the beginning...
#   publishedAt                               2012-05-01T13:53:02.000Z
#   video Id                                               jPJb_Cl1AcU
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-05-01 13:53:02
#   logViews                                                   4.77068
#   Name: 21, dtype: object,
#   viewCount                                                      283
#   likeCount                                                        7
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     7
#   title             Minecraft Let's Play Episode 1 - Beautiful Seed!
#   description      This seed is really nice hopefully you guys wi...
#   publishedAt                               2012-04-21T04:34:39.000Z
#   video Id                                               dILPZ8xXDo0
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-04-21 04:34:39
#   logViews                                                   5.64897
#   Name: 23, dtype: object,
#   viewCount                                                      180
#   likeCount                                                        4
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title                               Minecraft - Update On My World
#   description      (Insert my time wasted on failing) xD Hope you...
#   publishedAt                               2012-05-22T00:55:51.000Z
#   video Id                                               B37Qmtww3-s
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-05-22 00:55:51
#   logViews                                                    5.1985
#   Name: 18, dtype: object,
#   viewCount                                                      251
#   likeCount                                                        5
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     6
#   title            Minecraft - Let's Play Ep 6: Landscaping & Bunker
#   description      I'm making a new wheat farm in the area that I...
#   publishedAt                               2012-06-17T19:15:25.000Z
#   video Id                                               g0Vv4UltRJ0
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-06-17 19:15:25
#   logViews                                                   5.52943
#   Name: 14, dtype: object,
#   viewCount                                                      151
#   likeCount                                                        9
#   dislikeCount                                                     5
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title                                      Delver - A Blocky Game!
#   description      Please leave me some feed back, I put more eff...
#   publishedAt                               2012-09-23T05:39:03.000Z
#   video Id                                               1ir3Ks06Ksc
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-09-23 05:39:03
#   logViews                                                   5.02388
#   Name: 8, dtype: object,
#   viewCount                                                      134
#   likeCount                                                        3
#   dislikeCount                                                     3
#   favoriteCount                                                    0
#   commentCount                                                     9
#   title            Minecraft - Let's Play Ep 11: The Search Is Over!
#   description      Ben's channel: http://www.youtube.com/extrakzc...
#   publishedAt                               2012-09-21T02:22:15.000Z
#   video Id                                               MkWAcLHvvbo
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-09-21 02:22:15
#   logViews                                                   4.90527
#   Name: 9, dtype: object,
#   viewCount                                                      241
#   likeCount                                                        2
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title              Minecraft - Let's Play Ep 9: Hey, A Let's Play!
#   description      Sorry for some parts of unsynced audio on some...
#   publishedAt                               2012-08-22T23:29:49.000Z
#   video Id                                               nM8r6hRrRIM
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-08-22 23:29:49
#   logViews                                                   5.48894
#   Name: 10, dtype: object,
#   viewCount                                                      514
#   likeCount                                                        4
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     1
#   title                   Minecraft - Let's Play Ep 8: NPC Village!?
#   description      So we're going to go venture out and look for ...
#   publishedAt                               2012-06-27T01:50:25.000Z
#   video Id                                               vZ790i18DVE
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-06-27 01:50:25
#   logViews                                                   6.24417
#   Name: 12, dtype: object,
#   viewCount                                                      123
#   likeCount                                                        4
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                     6
#   title            Minecraft - Let's Play Ep 13: I'm Finished! I ...
#   description      Hope you enjoyed! Thanks for watching have a g...
#   publishedAt                               2012-10-09T02:26:15.000Z
#   video Id                                               17CGrprw5Wc
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-10-09 02:26:15
#   logViews                                                   4.82028
#   Name: 6, dtype: object,
#   viewCount                                                      119
#   likeCount                                                        4
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                     9
#   title                    Minecraft - Let's Play Ep 14: The Bedroom
#   description      Sorry, I forgot to mention that I did A LOT OF...
#   publishedAt                               2012-10-20T07:28:42.000Z
#   video Id                                               yzbdZcTCoy0
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-10-20 07:28:42
#   logViews                                                   4.78749
#   Name: 5, dtype: object,
#   viewCount                                                      105
#   likeCount                                                        4
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                  Minecraft - Let's Play Ep 12: Jungle Trees!
#   description      Hey, sorry for the gaps inbetween my "Let's Pl...
#   publishedAt                               2012-10-06T00:34:57.000Z
#   video Id                                               YJSEg56qZs8
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-10-06 00:34:57
#   logViews                                                   4.66344
#   Name: 7, dtype: object,
#   viewCount                                                     1440
#   likeCount                                                        7
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     6
#   title            Minecraft - MineZ Episode 2: I think I'm Infec...
#   description      Well due to the fact that the entire recording...
#   publishedAt                               2012-07-22T23:13:29.000Z
#   video Id                                               YeYv7vj7W7Y
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2012-07-22 23:13:29
#   logViews                                                   7.27309
#   Name: 11, dtype: object,
#   viewCount                                                      102
#   likeCount                                                        4
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                          Minecraft - Let's Play Ep 16: Poof!
#   description      Back, back, back, back again....\r\n\r\nDonate...
#   publishedAt                               2013-02-08T03:40:56.000Z
#   video Id                                               nKu9fhuo8FM
#   channel Id                                UCwRGQapSgTW9xba17OCjgXA
#   PublishedAt                                    2013-02-08 03:40:56
#   logViews                                                   4.63473
#   Name: 2, dtype: object],
#  'UCls-lXo-657sDXtwB-8lGUw': [viewCount                                                     2690
#   likeCount                                                       21
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     3
#   title                                     M18 Hellcat w/ MaxL_1023
#   description      Following around MaxL_1023 in the completely O...
#   publishedAt                               2014-06-27T15:32:42.000Z
#   video Id                                               ZL5ssZu9mvY
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-27 15:32:42
#   logViews                                                   7.89767
#   Name: 32, dtype: object,
#   viewCount                                                     1506
#   likeCount                                                       17
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     1
#   title                   Flat Scissors and Rolling Scissors in WoWP
#   description      How can these two typical aerial maneuvers be ...
#   publishedAt                               2014-06-11T16:07:26.000Z
#   video Id                                               n12nMtVqm4E
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-11 16:07:26
#   logViews                                                   7.31788
#   Name: 38, dtype: object,
#   viewCount                                                     3655
#   likeCount                                                       43
#   dislikeCount                                                     4
#   favoriteCount                                                    0
#   commentCount                                                    12
#   title               DJI Phantom 2 Unboxing, Assembly, First Flight
#   description      Just got my Phantom 2 Quadcopter, and this vid...
#   publishedAt                               2014-06-01T04:34:30.000Z
#   video Id                                               EfIBVuMjuhM
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-01 04:34:30
#   logViews                                                   8.20412
#   Name: 46, dtype: object,
#   viewCount                                                     2777
#   likeCount                                                       27
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                                        T32 Review Commentary
#   description      Taking a look at the T32.  It's supposedly bet...
#   publishedAt                               2014-06-25T17:12:50.000Z
#   video Id                                               QDGZkJ-RI7E
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-25 17:12:50
#   logViews                                                   7.92949
#   Name: 34, dtype: object,
#   viewCount                                                     1411
#   likeCount                                                       15
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                             XF5U - Pancake Review Commentary
#   description      I love quirky planes/tanks, so I was very exci...
#   publishedAt                               2014-06-05T14:10:26.000Z
#   video Id                                               rZWNQhppKjM
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-05 14:10:26
#   logViews                                                   7.25276
#   Name: 43, dtype: object,
#   viewCount                                                     2092
#   likeCount                                                       23
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title                 T110E4 Review Commentary - Heavy in disguise
#   description      Shadowing precambrian in the E4, I explain why...
#   publishedAt                               2014-06-30T17:20:15.000Z
#   video Id                                               1jIwogIXt5k
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-30 17:20:15
#   logViews                                                   7.64635
#   Name: 31, dtype: object,
#   viewCount                                                     2615
#   likeCount                                                       21
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                                        T29 Review Commentary
#   description      Has there ever been a time when the T29 wasn't...
#   publishedAt                               2014-06-25T17:41:30.000Z
#   video Id                                               mPeJqvhQKYw
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-25 17:41:30
#   logViews                                                    7.8694
#   Name: 33, dtype: object,
#   viewCount                                                     2347
#   likeCount                                                       25
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                                       Maus Review Commentary
#   description      Taking a look at a tank that's usually the but...
#   publishedAt                               2014-06-19T21:26:15.000Z
#   video Id                                               GIdE5MrF4N8
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-19 21:26:15
#   logViews                                                   7.76132
#   Name: 36, dtype: object,
#   viewCount                                                     2138
#   likeCount                                                       25
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                    12
#   title                                 Type 64 Murovanka scout work
#   description      Watching dualmaster333 work his magic on Murov...
#   publishedAt                               2014-07-01T18:56:44.000Z
#   video Id                                               KHeDY5pMQ5c
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-07-01 18:56:44
#   logViews                                                   7.66809
#   Name: 30, dtype: object,
#   viewCount                                                     1988
#   likeCount                                                       27
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                                           WZ-120 Cliff Carry
#   description      Completing his review of the Chinese medium li...
#   publishedAt                               2014-06-10T15:49:57.000Z
#   video Id                                               uWWHVarQWJ4
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-10 15:49:57
#   logViews                                                   7.59539
#   Name: 40, dtype: object,
#   viewCount                                                     2124
#   likeCount                                                       26
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title                                  Conqueror Review Commentary
#   description      I spend more time talking about low effective ...
#   publishedAt                               2014-06-23T15:56:42.000Z
#   video Id                                               7yIj2-X_l2I
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-23 15:56:42
#   logViews                                                   7.66153
#   Name: 35, dtype: object,
#   viewCount                                                      583
#   likeCount                                                        4
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                     2
#   title                                        F7F Review Commentary
#   description      One of my new favorite planes, the tier 7 US h...
#   publishedAt                               2014-06-02T18:11:20.000Z
#   video Id                                               JYvGXyM4zY8
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-02 18:11:20
#   logViews                                                    6.3699
#   Name: 44, dtype: object,
#   viewCount                                                     2544
#   likeCount                                                       30
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                                       E-75 Review Commentary
#   description      Taking a look at what makes one of the best ta...
#   publishedAt                               2014-05-30T16:34:35.000Z
#   video Id                                               f0ZiPXV94JU
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-05-30 16:34:35
#   logViews                                                   7.84189
#   Name: 48, dtype: object,
#   viewCount                                                     1478
#   likeCount                                                       28
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     3
#   title                                     T-34-1 Review Commentary
#   description      Medium tanks generally aren't very good before...
#   publishedAt                               2014-06-06T16:53:00.000Z
#   video Id                                               GS-esnyPjkY
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-06 16:53:00
#   logViews                                                   7.29912
#   Name: 42, dtype: object,
#   viewCount                                                     3760
#   likeCount                                                       63
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                    16
#   title                                   Pershing Review Commentary
#   description      Taking a look at a tank so OLD that it's new a...
#   publishedAt                               2014-07-28T18:34:39.000Z
#   video Id                                               _XKyDdwOBsA
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-07-28 18:34:39
#   logViews                                                   8.23244
#   Name: 26, dtype: object,
#   viewCount                                                      910
#   likeCount                                                       10
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title                                       P51D Review Commentary
#   description      Antiledo goes through the ins and outs of one ...
#   publishedAt                               2014-07-07T20:10:41.000Z
#   video Id                                               ocwvQLg2OGw
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-07-07 20:10:41
#   logViews                                                   6.81454
#   Name: 29, dtype: object,
#   viewCount                                                     3328
#   likeCount                                                       19
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     3
#   title                   Rhm.-Borsig Waffentrager Review Commentary
#   description      Following around Kewei as he effortlessly puts...
#   publishedAt                               2014-05-28T16:38:58.000Z
#   video Id                                               T9SxiLrppSo
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-05-28 16:38:58
#   logViews                                                   8.11043
#   Name: 49, dtype: object,
#   viewCount                                                     3044
#   likeCount                                                       15
#   dislikeCount                                                     4
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                                       E100 Review Commentary
#   description      One of the best true heavy tanks in the game, ...
#   publishedAt                               2014-06-02T15:44:58.000Z
#   video Id                                               svByutHw-F8
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-02 15:44:58
#   logViews                                                   8.02126
#   Name: 45, dtype: object,
#   viewCount                                                     3493
#   likeCount                                                       47
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                    11
#   title                                       IS-3 Review Commentary
#   description      Precambrian wrote up a full review of this mag...
#   publishedAt                               2014-07-10T18:49:40.000Z
#   video Id                                               XfbRwjT1Pv8
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-07-10 18:49:40
#   logViews                                                    8.1588
#   Name: 28, dtype: object,
#   viewCount                                                     5243
#   likeCount                                                       50
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                    14
#   title                                     T-34-2 Review Commentary
#   description      The T-34-2 is unique in that it has two viable...
#   publishedAt                               2014-06-09T23:19:52.000Z
#   video Id                                               nwuE0Z2VEu0
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-09 23:19:52
#   logViews                                                   8.56484
#   Name: 41, dtype: object,
#   viewCount                                                     3446
#   likeCount                                                       34
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title                                       IS-6 Review Commentary
#   description      One of my favorite premium money makers, the I...
#   publishedAt                               2014-06-17T22:09:00.000Z
#   video Id                                               2Q_XhQ_ONvM
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-17 22:09:00
#   logViews                                                   8.14526
#   Name: 37, dtype: object,
#   viewCount                                                     3663
#   likeCount                                                       23
#   dislikeCount                                                     3
#   favoriteCount                                                    0
#   commentCount                                                    10
#   title                                   Tiger II Review Commentary
#   description      Please don't watch this.  Read Garbad's full r...
#   publishedAt                               2014-05-30T17:10:49.000Z
#   video Id                                               1sp3TgqeLHE
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-05-30 17:10:49
#   logViews                                                   8.20631
#   Name: 47, dtype: object,
#   viewCount                                                    13034
#   likeCount                                                       49
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     3
#   title                                 AMX 50 100 Review Commentary
#   description      Autoloader madness!  Full writeup here: http:/...
#   publishedAt                               2014-07-14T17:45:40.000Z
#   video Id                                               xq-SkYDZE-k
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-07-14 17:45:40
#   logViews                                                   9.47539
#   Name: 27, dtype: object,
#   viewCount                                                     1113
#   likeCount                                                       11
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     2
#   title                                      XP-50 Review Commentary
#   description      TL;DR: there's nothing better.  Full writeup h...
#   publishedAt                               2014-06-10T17:11:41.000Z
#   video Id                                               ztuKKzLyW50
#   channel Id                                UCls-lXo-657sDXtwB-8lGUw
#   PublishedAt                                    2014-06-10 17:11:41
#   logViews                                                   7.01571
#   Name: 39, dtype: object],
#  'UC8vKgvr3IesiwvMQ1XoKcCg': [viewCount                                                       67
#   likeCount                                                        0
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title                            Tras mil veces no se vuelve un sí
#   description      Facebook: www.facebook.com/TrasMilVecesNo\r\nT...
#   publishedAt                               2012-12-03T13:18:55.000Z
#   video Id                                               kNdrDfbY1RM
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2012-12-03 13:18:55
#   logViews                                                   4.21951
#   Name: 64, dtype: object,
#   viewCount                                                      377
#   likeCount                                                        3
#   dislikeCount                                                     2
#   favoriteCount                                                    0
#   commentCount                                                     1
#   title                                               Tributo a Sara
#   description      Pequeño homenaje a mi amiga Sara con fotos de ...
#   publishedAt                               2011-02-19T00:43:10.000Z
#   video Id                                               pwIpH5b9eUo
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2011-02-19 00:43:10
#   logViews                                                   5.93489
#   Name: 71, dtype: object,
#   viewCount                                                      115
#   likeCount                                                        0
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     1
#   title                               Legionarios del Cristo de Mena
#   description      Legionarios que acompañan al Cristo de Mena el...
#   publishedAt                               2012-04-09T15:24:17.000Z
#   video Id                                               N4HRmSzmiI0
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2012-04-09 15:24:17
#   logViews                                                   4.75359
#   Name: 67, dtype: object,
#   viewCount                                                       52
#   likeCount                                                        0
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title                                               Cristo de Mena
#   description      Cristo de Mena o Cristo de la Buena Muerte el ...
#   publishedAt                               2012-04-09T19:48:59.000Z
#   video Id                                               Zjsb1v2YW3c
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2012-04-09 19:48:59
#   logViews                                                   3.97029
#   Name: 66, dtype: object,
#   viewCount                                                      142
#   likeCount                                                        1
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     1
#   title                                         Todos sois un regalo
#   description      Vídeo homenaje a mis amigos del hostal Valenci...
#   publishedAt                               2011-07-01T16:10:52.000Z
#   video Id                                               f_dN2S5siJY
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2011-07-01 16:10:52
#   logViews                                                   4.96284
#   Name: 69, dtype: object,
#   viewCount                                                      112
#   likeCount                                                        0
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title                                 Virgen de la Soledad de Mena
#   description      Virgen de la Soledad de Mena el Jueves Santo e...
#   publishedAt                               2012-04-09T19:55:26.000Z
#   video Id                                               gRraHiUZVAE
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2012-04-09 19:55:26
#   logViews                                                   4.72739
#   Name: 65, dtype: object,
#   viewCount                                                      819
#   likeCount                                                        2
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     1
#   title                      Procesión de la Borriquita en Santaella
#   description      Procesión de La Borriquita en Santaella (Córdo...
#   publishedAt                               2012-04-01T12:38:33.000Z
#   video Id                                               0wPxNOFZOB8
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2012-04-01 12:38:33
#   logViews                                                    6.7093
#   Name: 68, dtype: object,
#   viewCount                                                       84
#   likeCount                                                        1
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title             Taxi: "Quiero un Camino" en Marinaleda (Sevilla)
#   description      Taxi cantando "Quiero un camino" recordando a ...
#   publishedAt                               2013-04-28T17:05:00.000Z
#   video Id                                               njq5OLbWXxA
#   channel Id                                UC8vKgvr3IesiwvMQ1XoKcCg
#   PublishedAt                                    2013-04-28 17:05:00
#   logViews                                                   4.44265
#   Name: 52, dtype: object,
#   viewCount                                                      128
#   likeCount                                                        0
#   dislikeCount                                                     0
#   favoriteCount                                                    0
# ...
#   commentCount                                                     3
#   title                      Colossal Myopia Guitar Hero Custom Song
#   description      Reworked the tapping in this one, decided to m...
#   publishedAt                               2011-04-22T22:06:40.000Z
#   video Id                                               Fw300ojZsTo
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-22 22:06:40
#   logViews                                                    5.0814
#   Name: 263, dtype: object,
#   viewCount                                                     1292
#   likeCount                                                        5
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     8
#   title                            War March Guitar Hero Custom Song
#   description      My chart of War March by Andy James.\r\r\n\r\r...
#   publishedAt                               2011-05-14T02:29:50.000Z
#   video Id                                               IWv-t_ekntY
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-05-14 02:29:50
#   logViews                                                   7.16472
#   Name: 261, dtype: object,
#   viewCount                                                      251
#   likeCount                                                        3
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                    13
#   title                                 Flex Guitar Hero Custom Song
#   description      My chart of Flex by Mike Orlando\r\n\r\nGuitar...
#   publishedAt                               2011-04-22T04:35:30.000Z
#   video Id                                               RYkR95Kntw8
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-22 04:35:30
#   logViews                                                   5.52943
#   Name: 266, dtype: object,
#   viewCount                                                     1575
#   likeCount                                                       13
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title                  Building the Church Guitar Hero Custom Song
#   description      My chart of Building the Church by Steve Vai.\...
#   publishedAt                               2011-06-06T01:43:19.000Z
#   video Id                                               ahdSLp8PU0E
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-06-06 01:43:19
#   logViews                                                   7.36265
#   Name: 256, dtype: object,
#   viewCount                                                      618
#   likeCount                                                        7
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     2
#   title               The Dark Eternal Night Guitar Hero Custom Song
#   description      My Chart of The Dark Eternal Night by Dream Th...
#   publishedAt                               2011-04-10T05:54:00.000Z
#   video Id                                               1sEqIs-Fea0
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-10 05:54:00
#   logViews                                                   6.42811
#   Name: 271, dtype: object,
#   viewCount                                                      289
#   likeCount                                                        7
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                             Movement Guitar Hero Custom Song
#   description      My chart of Movement by Michael Orlando.\r\n\r...
#   publishedAt                               2010-12-03T02:26:40.000Z
#   video Id                                               cyvkQhkD08c
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2010-12-03 02:26:40
#   logViews                                                   5.66988
#   Name: 276, dtype: object,
#   viewCount                                                      263
#   likeCount                                                        6
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     2
#   title              The Unwavering Collapse Guitar Hero Custom Song
#   description      My chart of The Unwavering Collapse by those g...
#   publishedAt                               2011-04-16T17:36:34.000Z
#   video Id                                               ejO9ED0BCPY
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-16 17:36:34
#   logViews                                                   5.57595
#   Name: 269, dtype: object,
#   viewCount                                                      558
#   likeCount                                                        3
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title                         Under it All Guitar Hero Custom Song
#   description      My chart of Under it All by Steve Vai.\r\n\r\n...
#   publishedAt                               2011-04-22T04:54:56.000Z
#   video Id                                               NIrNK4z1x7w
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-22 04:54:56
#   logViews                                                   6.32615
#   Name: 265, dtype: object,
#   viewCount                                                      286
#   likeCount                                                        2
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     5
#   title                             Escaping Guitar Hero Custom Song
#   description      My Chart of Escaping by Kiko Loureiro.\r\n\r\n...
#   publishedAt                               2011-04-10T05:21:34.000Z
#   video Id                                               nZ-CBZbb4HY
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-10 05:21:34
#   logViews                                                   5.65948
#   Name: 272, dtype: object,
#   viewCount                                                      680
#   likeCount                                                        3
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     6
#   title                   Gray Pianos Flying Guitar Hero Custom Song
#   description      My Chart of Gray Pianos Flying by Shawn Lane.\...
#   publishedAt                               2011-04-10T04:58:14.000Z
#   video Id                                               w6D6N_Mb1cE
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-10 04:58:14
#   logViews                                                   6.52356
#   Name: 273, dtype: object,
#   viewCount                                                      198
#   likeCount                                                        1
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     7
#   title                                 More Guitar Hero Custom Song
#   description      My chart of More by Bumblefoot.\r\n\r\nThis on...
#   publishedAt                               2011-06-06T01:25:34.000Z
#   video Id                                               gVFK0VqZgoc
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-06-06 01:25:34
#   logViews                                                    5.2933
#   Name: 257, dtype: object,
#   viewCount                                                      208
#   likeCount                                                        3
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     8
#   title                             Breaking Guitar Hero Custom Song
#   description      My chart of Breaking by Bumblefoot.\r\n\r\nRea...
#   publishedAt                               2010-11-28T19:38:06.000Z
#   video Id                                               ilPT0_KTA4Y
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2010-11-28 19:38:06
#   logViews                                                   5.34233
#   Name: 278, dtype: object,
#   viewCount                                                      481
#   likeCount                                                        4
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title                        Meteor Shower Guitar Hero Custom Song
#   description      My chart of Meteor Shower by Katsu Ohta.\r\n\r...
#   publishedAt                               2011-06-06T01:58:21.000Z
#   video Id                                               4m42W-1SKgg
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-06-06 01:58:21
#   logViews                                                   6.17794
#   Name: 255, dtype: object,
#   viewCount                                                     9221
#   likeCount                                                       62
#   dislikeCount                                                     4
#   favoriteCount                                                    0
#   commentCount                                                    19
#   title                   I Know You're Here Guitar Hero Custom Song
#   description      My chart of I Know You're Here by Steve Vai.\r...
#   publishedAt                               2011-05-14T03:20:42.000Z
#   video Id                                               m1PHC8Zh9gE
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-05-14 03:20:42
#   logViews                                                   9.12935
#   Name: 260, dtype: object,
#   viewCount                                                      420
#   likeCount                                                        2
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     3
#   title                          Superheroes Guitar Hero Custom Song
#   description      My chart of Superheroes by Racer X.\r\n\r\nWan...
#   publishedAt                               2011-04-28T00:01:01.000Z
#   video Id                                               GsTUBnm-4oc
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-28 00:01:01
#   logViews                                                   6.04263
#   Name: 262, dtype: object,
#   viewCount                                                      386
#   likeCount                                                        6
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     4
#   title            The Tragedy of Modern Ages Guitar Hero Custom ...
#   description      My Chart of The Tragedy of Modern Ages by Revo...
#   publishedAt                               2011-04-10T03:30:32.000Z
#   video Id                                               YcuBt5RwzZo
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-10 03:30:32
#   logViews                                                   5.95842
#   Name: 274, dtype: object,
#   viewCount                                                     2695
#   likeCount                                                        9
#   dislikeCount                                                     1
#   favoriteCount                                                    0
#   commentCount                                                     3
#   title                       Universal Mind Guitar Hero Custom Song
#   description      My Chart of Universal Mind by Liquid Tension E...
#   publishedAt                               2011-04-22T04:27:05.000Z
#   video Id                                               5mWe_XAlMJ8
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-22 04:27:05
#   logViews                                                   7.89952
#   Name: 267, dtype: object,
#   viewCount                                                      311
#   likeCount                                                        2
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                    11
#   title                       Through The Fire and the Flames Custom
#   description      So remember when I charted this like a ways ba...
#   publishedAt                               2011-04-22T21:36:55.000Z
#   video Id                                               gGgDOmZIvY4
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2011-04-22 21:36:55
#   logViews                                                     5.743
#   Name: 264, dtype: object,
#   viewCount                                                      289
#   likeCount                                                        2
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     9
#   title            The Washing Away of Wrong Guitar Hero Custom Song
#   description      My chart of The Washing Away of Wrong by John ...
#   publishedAt                               2010-12-18T04:34:25.000Z
#   video Id                                               uSYqnlw8O44
#   channel Id                                UCxg-kNjuMDVy13-s-zPzeRg
#   PublishedAt                                    2010-12-18 04:34:25
#   logViews                                                   5.66988
#   Name: 275, dtype: object]}

# %%
import collections

def cosine_similarity(title1, title2):
    title1 = str(title1)
    title2 = str(title2)
    bag1 = collections.defaultdict(int)
    bag2 = collections.defaultdict(int)
    for word in title1.split():
        bag1[word] += 1
    for word in title2.split():
        bag2[word] += 1
     
    result = 0
    for word in bag1:
        if word in bag2:
            result += bag1[word] * bag2[word]
    norm1 = sum([v**2 for v in bag1.values()])**(1/2.)
    norm2 = sum([v**2 for v in bag2.values()])**(1/2.)
    result /= (norm1 * norm2)
    return result

# %%
y_test_list = list(y_test)
sum([(y_test_list[i]-y_pred[i])**2 for i in range(1024)])/1024.
# Out:
# 1.5604569170551388

# %%
# Out:
# [(0.0, viewCount                                540
#   likeCount                                  1
#   dislikeCount                               2
#   favoriteCount                              0
#   commentCount                               1
#   title            A Super Maconha das Maconha
#   description                              NaN
#   publishedAt         2016-08-29T13:17:46.000Z
#   video Id                         Uw-N_KqvbAY
#   channel Id          UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt              2016-08-29 13:17:46
#   logViews                             6.29342
#   Name: 49844, dtype: object),
#  (0.0, viewCount                                6403
#   likeCount                                  35
#   dislikeCount                                3
#   favoriteCount                               0
#   commentCount                                8
#   title            Onda gigante engole surfista
#   description                               NaN
#   publishedAt          2016-09-01T23:43:12.000Z
#   video Id                          WmyM9h4M6Xk
#   channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt               2016-09-01 23:43:12
#   logViews                              8.76468
#   Name: 49843, dtype: object),
#  (0.0, viewCount                                          1435
#   likeCount                                            14
#   dislikeCount                                          0
#   favoriteCount                                         0
#   commentCount                                          1
#   title            Novo painel R1 2016 299 km de 5 marcha
#   description                                         NaN
#   publishedAt                    2016-09-01T23:44:30.000Z
#   video Id                                    Mdmuh_x9xO8
#   channel Id                     UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                         2016-09-01 23:44:30
#   logViews                                        7.26962
#   Name: 49842, dtype: object),
#  (0.0, viewCount                                        14930
#   likeCount                                          106
#   dislikeCount                                       219
#   favoriteCount                                        0
#   commentCount                                        52
#   title               Milagre barriga tanquinho em 1 dia
#   description      Define sua barriga com o gel redutor.
#   publishedAt                   2016-10-19T20:11:33.000Z
#   video Id                                   iUXsPEixM10
#   channel Id                    UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                        2016-10-19 20:11:33
#   logViews                                       9.61119
#   Name: 49841, dtype: object),
#  (0.0, viewCount                                 124
#   likeCount                                   1
#   dislikeCount                                0
#   favoriteCount                               0
#   commentCount                                0
#   title            Subindo a serra em 6 minutos
#   description                               NaN
#   publishedAt          2016-11-25T01:42:08.000Z
#   video Id                          6JLaz39WmFs
#   channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt               2016-11-25 01:42:08
#   logViews                              4.82831
#   Name: 49840, dtype: object),
#  (0.0, viewCount                                                      108
#   likeCount                                                        1
#   dislikeCount                                                     0
#   favoriteCount                                                    0
#   commentCount                                                     0
#   title            277 km por hr de quarta marcha; ainda faltava ...
#   description                                                    NaN
#   publishedAt                               2016-11-25T02:52:53.000Z
#   video Id                                               BTvKJTN5OoU
#   channel Id                                UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                                    2016-11-25 02:52:53
#   logViews                                                   4.69135
#   Name: 49839, dtype: object),
#  (0.0, viewCount                              174
#   likeCount                                2
#   dislikeCount                             0
#   favoriteCount                            0
#   commentCount                             0
#   title            Acelerando forte na praia
#   description                            NaN
#   publishedAt       2016-11-25T07:49:45.000Z
#   video Id                       Fz4tAVxzfIM
#   channel Id        UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt            2016-11-25 07:49:45
#   logViews                           5.16479
#   Name: 49838, dtype: object),
#  (0.0, viewCount                                                84
#   likeCount                                                 1
#   dislikeCount                                              0
#   favoriteCount                                             0
#   commentCount                                              0
#   title                       Cavalo de pau na �gua de jetsky
#   description      360 no cavalo de pau no jetsky final v�deo
#   publishedAt                        2017-03-18T21:04:40.000Z
#   video Id                                        EAZ0VAIBZnE
#   channel Id                         UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                             2017-03-18 21:04:40
#   logViews                                            4.44265
#   Name: 49837, dtype: object),
#  (0.0, viewCount                                   76
#   likeCount                                    0
#   dislikeCount                                 0
#   favoriteCount                                0
#   commentCount                                 0
#   title            Viva la Vida.  Arctic Monkeys
#   description        La vida um present de Dios.
#   publishedAt           2017-04-05T18:45:18.000Z
#   video Id                           RGQYaIoji2E
#   channel Id            UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                2017-04-05 18:45:18
#   logViews                               4.34381
#   Name: 49836, dtype: object),
#  (0.0, viewCount                                 23
#   likeCount                                  0
#   dislikeCount                               0
#   favoriteCount                              0
#   commentCount                               0
#   title            Depeche Mode   It's No Good
#   description                     DANCA MUITO.
#   publishedAt         2017-06-25T19:12:16.000Z
#   video Id                         Scp3JH3eVLw
#   channel Id          UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt              2017-06-25 19:12:16
#   logViews                             3.17805
#   Name: 49835, dtype: object),
#  (0.0, viewCount                                               72
#   likeCount                                                0
#   dislikeCount                                             0
#   favoriteCount                                            0
#   commentCount                                             0
#   title                                  Caribe de S�o Paulo
#   description      Mar Azul em  litoral sul  Sp. Coisa linda
#   publishedAt                       2017-10-13T22:12:22.000Z
#   video Id                                       0Lqfk3AcGNo
#   channel Id                        UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                            2017-10-13 22:12:22
#   logViews                                           4.29046
#   Name: 49834, dtype: object),
#  (0.0, viewCount                                    37
#   likeCount                                     0
#   dislikeCount                                  1
#   favoriteCount                                 0
#   commentCount                                  0
#   title                            Manobra Jetski
#   description      R� engatada e acelerando forte
#   publishedAt            2017-10-13T22:16:33.000Z
#   video Id                            2PlglUM_97U
#   channel Id             UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                 2017-10-13 22:16:33
#   logViews                                3.63759
#   Name: 49833, dtype: object),
#  (0.0, viewCount                               56
#   likeCount                                0
#   dislikeCount                             0
#   favoriteCount                            0
#   commentCount                             0
#   title            Baleia Encalhada na praia
#   description                            NaN
#   publishedAt       2017-11-10T03:34:55.000Z
#   video Id                       LUNnmpxR0AI
#   channel Id        UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt            2017-11-10 03:34:55
#   logViews                           4.04305
#   Name: 49831, dtype: object),
#  (0.0, viewCount                                               47
#   likeCount                                                0
#   dislikeCount                                             0
#   favoriteCount                                            0
#   commentCount                                             0
#   title            Jetsky quase provoca acidente  com.lancha
#   description      Jetsky  voando  em.onda feita  por lancha
#   publishedAt                       2017-12-25T14:59:38.000Z
#   video Id                                       XDuVojCKdmY
#   channel Id                        UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                            2017-12-25 14:59:38
#   logViews                                            3.8712
#   Name: 49829, dtype: object),
#  (0.0, viewCount                            6880
#   likeCount                              12
#   dislikeCount                           12
#   favoriteCount                           0
#   commentCount                            0
#   title             Gostosa andando  na rua
#   description                Gostosa na ruq
#   publishedAt      2017-12-25T17:54:18.000Z
#   video Id                      0B7zukm9Suc
#   channel Id       UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt           2017-12-25 17:54:18
#   logViews                          8.83652
#   Name: 49828, dtype: object),
#  (0.0, viewCount                                     3485
#   likeCount                                        9
#   dislikeCount                                     0
#   favoriteCount                                    0
#   commentCount                                     1
#   title                     Gostosa bunduda no metro
#   description      Bunda bem grande  andando  na rua
#   publishedAt               2017-12-25T17:56:19.000Z
#   video Id                               6FVaqE1QkEU
#   channel Id                UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                    2017-12-25 17:56:19
#   logViews                                   8.15651
#   Name: 49827, dtype: object),
#  (0.0, viewCount                                   14179
#   likeCount                                      39
#   dislikeCount                                    5
#   favoriteCount                                   0
#   commentCount                                    0
#   title                 Gostosa de macac�o Apertado
#   description      Muito gostosa andando na cal�ada
#   publishedAt              2018-02-19T18:38:11.000Z
#   video Id                              Z5wpAM9ctQ8
#   channel Id               UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                   2018-02-19 18:38:11
#   logViews                                  9.55959
#   Name: 49826, dtype: object),
#  (0.0, viewCount                                      1499
#   likeCount                                         6
#   dislikeCount                                      0
#   favoriteCount                                     0
#   commentCount                                      1
#   title                          Gostosas da Academia
#   description      As mais belas bundas das academias
#   publishedAt                2018-02-20T01:18:25.000Z
#   video Id                                KjAoyxGSRY0
#   channel Id                 UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                     2018-02-20 01:18:25
#   logViews                                    7.31322
#   Name: 49825, dtype: object),
#  (0.0, viewCount                              11175
#   likeCount                                 52
#   dislikeCount                               4
#   favoriteCount                              0
#   commentCount                               2
#   title            Empregada da bunda perfeita
#   description                              NaN
#   publishedAt         2018-07-20T18:35:57.000Z
#   video Id                         EEnILjJBeJ4
#   channel Id          UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt              2018-07-20 18:35:57
#   logViews                             9.32152
#   Name: 49823, dtype: object),
#  (0.0, viewCount                           17389
#   likeCount                              81
#   dislikeCount                            3
#   favoriteCount                           0
#   commentCount                            1
#   title                    A bunda perfeita
#   description                           NaN
#   publishedAt      2018-07-20T18:36:25.000Z
#   video Id                      p8zqFpGzeLE
#   channel Id       UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt           2018-07-20 18:36:25
#   logViews                          9.76365
#   Name: 49821, dtype: object),
#  (0.18257418583505536, viewCount                                     1271
#   likeCount                                        4
#   dislikeCount                                     4
#   favoriteCount                                    0
#   commentCount                                     1
#   title            Arrancando o Maior dente do mundo
#   description                 Super dente arrancado.
#   publishedAt               2017-10-13T22:24:18.000Z
#   video Id                               8NRkk_ncXxQ
#   channel Id                UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                    2017-10-13 22:24:18
#   logViews                                   7.14835
#   Name: 49832, dtype: object),
#  (0.18257418583505536, viewCount                                  18
#   likeCount                                   0
#   dislikeCount                                0
#   favoriteCount                               0
#   commentCount                                0
#   title            Jiu jitsu h� luta do s�culo.
#   description                               NaN
#   publishedAt          2018-05-01T17:14:13.000Z
#   video Id                          muRkXiVyoYQ
#   channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt               2018-05-01 17:14:13
#   logViews                              2.94444
#   Name: 49824, dtype: object),
#  (0.19999999999999996, viewCount                                  71
#   likeCount                                   0
#   dislikeCount                                0
#   favoriteCount                               0
#   commentCount                                1
#   title            Cachorro mais forte do mundo
#   description                               NaN
#   publishedAt          2017-11-10T14:55:18.000Z
#   video Id                          9rHI5zRctn0
#   channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt               2017-11-10 14:55:18
#   logViews                              4.27667
#   Name: 49830, dtype: object),
#  (0.33806170189140655, viewCount                                            9
#   likeCount                                            0
#   dislikeCount                                         0
#   favoriteCount                                        0
#   commentCount                                         0
#   title            O melhor boxeador do mundo Mike Tyson
#   description                 O soco mais forte do mundo
#   publishedAt                   2018-07-20T18:35:33.000Z
#   video Id                                   IH01uoDlroo
#   channel Id                    UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt                        2018-07-20 18:35:33
#   logViews                                       2.30259
#   Name: 49822, dtype: object),
#  (0.9999999999999998, viewCount                               18
#   likeCount                                0
#   dislikeCount                             0
#   favoriteCount                            0
#   commentCount                             0
#   title            Uma carta do melhor amigo
#   description      A carta que me fez chorar
#   publishedAt       2018-08-01T16:09:52.000Z
#   video Id                       JaegFu3_OGE
#   channel Id        UCa0o4WDOq1kJAyMETrPnpQg
#   PublishedAt            2018-08-01 16:09:52
#   logViews                           2.94444
#   Name: 49820, dtype: object)]

# %%
# Out:
# [viewCount                                540
#  likeCount                                  1
#  dislikeCount                               2
#  favoriteCount                              0
#  commentCount                               1
#  title            A Super Maconha das Maconha
#  description                              NaN
#  publishedAt         2016-08-29T13:17:46.000Z
#  video Id                         Uw-N_KqvbAY
#  channel Id          UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt              2016-08-29 13:17:46
#  logViews                             6.29342
#  Name: 49844, dtype: object, viewCount                                6403
#  likeCount                                  35
#  dislikeCount                                3
#  favoriteCount                               0
#  commentCount                                8
#  title            Onda gigante engole surfista
#  description                               NaN
#  publishedAt          2016-09-01T23:43:12.000Z
#  video Id                          WmyM9h4M6Xk
#  channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt               2016-09-01 23:43:12
#  logViews                              8.76468
#  Name: 49843, dtype: object, viewCount                                          1435
#  likeCount                                            14
#  dislikeCount                                          0
#  favoriteCount                                         0
#  commentCount                                          1
#  title            Novo painel R1 2016 299 km de 5 marcha
#  description                                         NaN
#  publishedAt                    2016-09-01T23:44:30.000Z
#  video Id                                    Mdmuh_x9xO8
#  channel Id                     UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                         2016-09-01 23:44:30
#  logViews                                        7.26962
#  Name: 49842, dtype: object, viewCount                                        14930
#  likeCount                                          106
#  dislikeCount                                       219
#  favoriteCount                                        0
#  commentCount                                        52
#  title               Milagre barriga tanquinho em 1 dia
#  description      Define sua barriga com o gel redutor.
#  publishedAt                   2016-10-19T20:11:33.000Z
#  video Id                                   iUXsPEixM10
#  channel Id                    UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                        2016-10-19 20:11:33
#  logViews                                       9.61119
#  Name: 49841, dtype: object, viewCount                                 124
#  likeCount                                   1
#  dislikeCount                                0
#  favoriteCount                               0
#  commentCount                                0
#  title            Subindo a serra em 6 minutos
#  description                               NaN
#  publishedAt          2016-11-25T01:42:08.000Z
#  video Id                          6JLaz39WmFs
#  channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt               2016-11-25 01:42:08
#  logViews                              4.82831
#  Name: 49840, dtype: object, viewCount                                                      108
#  likeCount                                                        1
#  dislikeCount                                                     0
#  favoriteCount                                                    0
#  commentCount                                                     0
#  title            277 km por hr de quarta marcha; ainda faltava ...
#  description                                                    NaN
#  publishedAt                               2016-11-25T02:52:53.000Z
#  video Id                                               BTvKJTN5OoU
#  channel Id                                UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                                    2016-11-25 02:52:53
#  logViews                                                   4.69135
#  Name: 49839, dtype: object, viewCount                              174
#  likeCount                                2
#  dislikeCount                             0
#  favoriteCount                            0
#  commentCount                             0
#  title            Acelerando forte na praia
#  description                            NaN
#  publishedAt       2016-11-25T07:49:45.000Z
#  video Id                       Fz4tAVxzfIM
#  channel Id        UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt            2016-11-25 07:49:45
#  logViews                           5.16479
#  Name: 49838, dtype: object, viewCount                                                84
#  likeCount                                                 1
#  dislikeCount                                              0
#  favoriteCount                                             0
#  commentCount                                              0
#  title                       Cavalo de pau na �gua de jetsky
#  description      360 no cavalo de pau no jetsky final v�deo
#  publishedAt                        2017-03-18T21:04:40.000Z
#  video Id                                        EAZ0VAIBZnE
#  channel Id                         UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                             2017-03-18 21:04:40
#  logViews                                            4.44265
#  Name: 49837, dtype: object, viewCount                                   76
#  likeCount                                    0
#  dislikeCount                                 0
#  favoriteCount                                0
#  commentCount                                 0
#  title            Viva la Vida.  Arctic Monkeys
#  description        La vida um present de Dios.
#  publishedAt           2017-04-05T18:45:18.000Z
#  video Id                           RGQYaIoji2E
#  channel Id            UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                2017-04-05 18:45:18
#  logViews                               4.34381
#  Name: 49836, dtype: object, viewCount                                 23
#  likeCount                                  0
#  dislikeCount                               0
#  favoriteCount                              0
#  commentCount                               0
#  title            Depeche Mode   It's No Good
#  description                     DANCA MUITO.
#  publishedAt         2017-06-25T19:12:16.000Z
#  video Id                         Scp3JH3eVLw
#  channel Id          UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt              2017-06-25 19:12:16
#  logViews                             3.17805
#  Name: 49835, dtype: object, viewCount                                               72
#  likeCount                                                0
#  dislikeCount                                             0
#  favoriteCount                                            0
#  commentCount                                             0
#  title                                  Caribe de S�o Paulo
#  description      Mar Azul em  litoral sul  Sp. Coisa linda
#  publishedAt                       2017-10-13T22:12:22.000Z
#  video Id                                       0Lqfk3AcGNo
#  channel Id                        UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                            2017-10-13 22:12:22
#  logViews                                           4.29046
#  Name: 49834, dtype: object, viewCount                                    37
#  likeCount                                     0
#  dislikeCount                                  1
#  favoriteCount                                 0
#  commentCount                                  0
#  title                            Manobra Jetski
#  description      R� engatada e acelerando forte
#  publishedAt            2017-10-13T22:16:33.000Z
#  video Id                            2PlglUM_97U
#  channel Id             UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                 2017-10-13 22:16:33
#  logViews                                3.63759
#  Name: 49833, dtype: object, viewCount                               56
#  likeCount                                0
#  dislikeCount                             0
#  favoriteCount                            0
#  commentCount                             0
#  title            Baleia Encalhada na praia
#  description                            NaN
#  publishedAt       2017-11-10T03:34:55.000Z
#  video Id                       LUNnmpxR0AI
#  channel Id        UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt            2017-11-10 03:34:55
#  logViews                           4.04305
#  Name: 49831, dtype: object, viewCount                                               47
#  likeCount                                                0
#  dislikeCount                                             0
#  favoriteCount                                            0
#  commentCount                                             0
#  title            Jetsky quase provoca acidente  com.lancha
#  description      Jetsky  voando  em.onda feita  por lancha
#  publishedAt                       2017-12-25T14:59:38.000Z
#  video Id                                       XDuVojCKdmY
#  channel Id                        UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                            2017-12-25 14:59:38
#  logViews                                            3.8712
#  Name: 49829, dtype: object, viewCount                            6880
#  likeCount                              12
#  dislikeCount                           12
#  favoriteCount                           0
#  commentCount                            0
#  title             Gostosa andando  na rua
#  description                Gostosa na ruq
#  publishedAt      2017-12-25T17:54:18.000Z
#  video Id                      0B7zukm9Suc
#  channel Id       UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt           2017-12-25 17:54:18
#  logViews                          8.83652
#  Name: 49828, dtype: object, viewCount                                     3485
#  likeCount                                        9
#  dislikeCount                                     0
#  favoriteCount                                    0
#  commentCount                                     1
#  title                     Gostosa bunduda no metro
#  description      Bunda bem grande  andando  na rua
#  publishedAt               2017-12-25T17:56:19.000Z
#  video Id                               6FVaqE1QkEU
#  channel Id                UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                    2017-12-25 17:56:19
#  logViews                                   8.15651
#  Name: 49827, dtype: object, viewCount                                   14179
#  likeCount                                      39
#  dislikeCount                                    5
#  favoriteCount                                   0
#  commentCount                                    0
#  title                 Gostosa de macac�o Apertado
#  description      Muito gostosa andando na cal�ada
#  publishedAt              2018-02-19T18:38:11.000Z
#  video Id                              Z5wpAM9ctQ8
#  channel Id               UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                   2018-02-19 18:38:11
#  logViews                                  9.55959
#  Name: 49826, dtype: object, viewCount                                      1499
#  likeCount                                         6
#  dislikeCount                                      0
#  favoriteCount                                     0
#  commentCount                                      1
#  title                          Gostosas da Academia
#  description      As mais belas bundas das academias
#  publishedAt                2018-02-20T01:18:25.000Z
#  video Id                                KjAoyxGSRY0
#  channel Id                 UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                     2018-02-20 01:18:25
#  logViews                                    7.31322
#  Name: 49825, dtype: object, viewCount                              11175
#  likeCount                                 52
#  dislikeCount                               4
#  favoriteCount                              0
#  commentCount                               2
#  title            Empregada da bunda perfeita
#  description                              NaN
#  publishedAt         2018-07-20T18:35:57.000Z
#  video Id                         EEnILjJBeJ4
#  channel Id          UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt              2018-07-20 18:35:57
#  logViews                             9.32152
#  Name: 49823, dtype: object, viewCount                           17389
#  likeCount                              81
#  dislikeCount                            3
#  favoriteCount                           0
#  commentCount                            1
#  title                    A bunda perfeita
#  description                           NaN
#  publishedAt      2018-07-20T18:36:25.000Z
#  video Id                      p8zqFpGzeLE
#  channel Id       UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt           2018-07-20 18:36:25
#  logViews                          9.76365
#  Name: 49821, dtype: object, viewCount                                     1271
#  likeCount                                        4
#  dislikeCount                                     4
#  favoriteCount                                    0
#  commentCount                                     1
#  title            Arrancando o Maior dente do mundo
#  description                 Super dente arrancado.
#  publishedAt               2017-10-13T22:24:18.000Z
#  video Id                               8NRkk_ncXxQ
#  channel Id                UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                    2017-10-13 22:24:18
#  logViews                                   7.14835
#  Name: 49832, dtype: object, viewCount                                  18
#  likeCount                                   0
#  dislikeCount                                0
#  favoriteCount                               0
#  commentCount                                0
#  title            Jiu jitsu h� luta do s�culo.
#  description                               NaN
#  publishedAt          2018-05-01T17:14:13.000Z
#  video Id                          muRkXiVyoYQ
#  channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt               2018-05-01 17:14:13
#  logViews                              2.94444
#  Name: 49824, dtype: object, viewCount                                  71
#  likeCount                                   0
#  dislikeCount                                0
#  favoriteCount                               0
#  commentCount                                1
#  title            Cachorro mais forte do mundo
#  description                               NaN
#  publishedAt          2017-11-10T14:55:18.000Z
#  video Id                          9rHI5zRctn0
#  channel Id           UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt               2017-11-10 14:55:18
#  logViews                              4.27667
#  Name: 49830, dtype: object, viewCount                                            9
#  likeCount                                            0
#  dislikeCount                                         0
#  favoriteCount                                        0
#  commentCount                                         0
#  title            O melhor boxeador do mundo Mike Tyson
#  description                 O soco mais forte do mundo
#  publishedAt                   2018-07-20T18:35:33.000Z
#  video Id                                   IH01uoDlroo
#  channel Id                    UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt                        2018-07-20 18:35:33
#  logViews                                       2.30259
#  Name: 49822, dtype: object, viewCount                               18
#  likeCount                                0
#  dislikeCount                             0
#  favoriteCount                            0
#  commentCount                             0
#  title            Uma carta do melhor amigo
#  description      A carta que me fez chorar
#  publishedAt       2018-08-01T16:09:52.000Z
#  video Id                       JaegFu3_OGE
#  channel Id        UCa0o4WDOq1kJAyMETrPnpQg
#  PublishedAt            2018-08-01 16:09:52
#  logViews                           2.94444
#  Name: 49820, dtype: object]

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

features = ['likeCount', 'dislikeCount', 'commentCount']
#real_features = [name+'-%d'%i for i in range(1,6) for name in features]
#df = pd.DataFrame(data)
df = df.dropna()
X = df[features]
y = df['logViews']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    
reg = GradientBoostingRegressor()
reg.fit(X_train, y_train)
print("R^2: {0}".format(reg.score(X_test, y_test)))
sns.set_style('whitegrid')
plt.figure(figsize=(10,12))
sns.barplot(x=reg.feature_importances_, y=features)
# Out:
# R^2: 0.7316192558752473

# %%
data[1]
# Out:
# {'likeCount-1': 4.0,
#  'dislikeCount-1': 2.0,
#  'viewCount-1': 583.0,
#  'commentCount-1': 2.0,
#  'likeCount-2': 25.0,
#  'dislikeCount-2': 0.0,
#  'viewCount-2': 2347.0,
#  'commentCount-2': 5.0,
#  'likeCount-3': 34.0,
#  'dislikeCount-3': 0.0,
#  'viewCount-3': 3446.0,
#  'commentCount-3': 4.0,
#  'likeCount-4': 49.0,
#  'dislikeCount-4': 0.0,
#  'viewCount-4': 13034.0,
#  'commentCount-4': 3.0,
#  'likeCount-5': 25.0,
#  'dislikeCount-5': 0.0,
#  'viewCount-5': 2138.0,
#  'commentCount-5': 12.0,
#  'trueViewCount': 7.01571242048723}
